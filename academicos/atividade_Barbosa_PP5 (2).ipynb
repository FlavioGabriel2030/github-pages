# %%
#1.	Desenvolva uma função que recebe uma mensagem e um número, ela mostra a mensagem e o número e não retorna nada.
#A função main chama a função passando os dois argumentos lidos, ou seja, digitados pelo usuário

# %%
def exibir_dados (mensagem,numero):
  print("__Progama__")
  print(f"A mensagem é {mensagem}\nO numero é {numero}")
def main():
  mensagem = input("Digite uma mensagem: ")
  numero = int(input("Digite um numero: "))
  exibir_dados(mensagem,numero)

# %%
if __name__== "__main__":
  main()
# Out:
# Digite uma mensagem: flavio
# Digite um numero: 22
# __Progama__
# A mensagem é flavio
# O numero é 22

# %%
#2.	Crie uma função para somar três valores. Ela recebe os três valores, calcula a soma e retorna o resultado do cálculo.
#A função main lê os três valores inteiros, chama a função passando os valores lidos e depois mostra o valor retornado pela função, ou seja, o resultado obtido

# %%
def somador3 (a):
  print("__Progama_Somador__")
  print(f"A sua soma foi de {a} ")
def main():
  resultado = 0
  for i in range(3):
    soma = int(input("Digite um valor que sera somado:"))
    resultado +=soma
  somador3(resultado)
  return somador3

# %%
if __name__=="__main__":
  main()
# Out:
# Digite um valor que sera somado:5
# Digite um valor que sera somado:7
# Digite um valor que sera somado:9
# __Progama_Somador__
# A sua soma foi de 21

# %%
#3.	Implemente uma função que calcula a idade de uma pessoa. Ela recebe o ano de nascimento da pessoa, faz o cálculo e retorna à idade.
#A função principal (main) lê o ano de nascimento digitado pelo usuário, chama a função e mostra o valor retornado pela função calcula.

# %%
def calcula_idade(a):
  print("__Progama de Idade__")
  print(f"A sua idade é de {a}")
def main():
  ano_de_nascimento =int(input("Digite seu ano de nascimento:"))
  idade = 2026 - ano_de_nascimento
  calcula_idade(idade)
  return calcula_idade
if __name__ == "__main__":
  main()
# Out:
# Digite seu ano de nascimento:2003
# __Progama de Idade__
# A sua idade é de 23

# %%
#4.	Use sua criatividade, elabore o problema (o enunciado) de um problema que usa função e resolva o problema proposto, ou seja, faça a implementação da função def e da função principal (main).
#Desenvolva um progama que calcula a quantidade dias letivos que falta para se formar na faculdade

# %%
def calculadora_da_liberdade(min_dias, max_dias):
  print("__Progama__")
  print(f"A quantidade mínima de dias letivos para se formar é de {min_dias:.2f}")
  print(f"A quantidade máxima de dias letivos para se formar é de {max_dias:.2f}")
def main():
  quantidade_de_semestres_restantes=float(input("digite a quantidade de semestres faltando"))
  semestre_min=100
  semestre_max=120
  calculadora_min = quantidade_de_semestres_restantes * semestre_min
  calculadora_max_ = quantidade_de_semestres_restantes * semestre_max
  calculadora_da_liberdade(calculadora_min, calculadora_max_)
if __name__=="__main__":
  main()
# Out:
# digite a quantidade de semestres faltando4.6
# __Progama__
# A quantidade mínima de dias letivos para se formar é de 460.00
# A quantidade máxima de dias letivos para se formar é de 552.00
